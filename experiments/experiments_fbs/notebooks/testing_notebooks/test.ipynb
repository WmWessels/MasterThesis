# %%
import openml
import pandas as pd

indexes = pd.read_csv("../data/good_indexes.csv", index_col = 0).iloc[:, 0]

for index_ in indexes:
    try:
        dataset = openml.datasets.get_dataset(index_, download_data = False)
    except:
        print(index_)
# Out:
# OpenML Dataset
# ...
# Name..........: anneal
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2014-04-06 23:19:24
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/1666876/anneal.arff
# OpenML URL....: https://www.openml.org/d/2
# # of features.: 39
# # of instances: 898
# OpenML Dataset
# ...
# Name..........: kr-vs-kp
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2014-04-06 23:19:28
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/3/kr-vs-kp.arff
# OpenML URL....: https://www.openml.org/d/3
# # of features.: 37
# # of instances: 3196
# OpenML Dataset
# ...
# Name..........: mfeat-factors
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2014-04-06 23:20:04
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/12/mfeat-factors.arff
# OpenML URL....: https://www.openml.org/d/12
# # of features.: 217
# # of instances: 2000
# OpenML Dataset
# ...

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined
